// %%
console.log("Warning: This uses JSlab kernel! Please install if you don't!");

// %% [markdown]
// # onEvents

// %% [markdown]
// ### JS (code.org)

// %% [raw]
// Syntax:
//
// onEvent("Object ID", "Action", function () {
//     // do something
// });

// %% [markdown]
// ### Sequential

// %% [raw]
// The JS in code.org can be sequential programming

// %% [markdown]
// ### Event Driven

// %% [raw]
// runs the code if and only the app got the input from user

// %% [markdown]
// ### Debugging

// %% [markdown]
// The process of fixing the problem occuring on the problem
//
// - Syntax Error: ex. forgets ;, }, or indents
// - Runtime Error: ex. segmentation fault, out of memory, memory leak, library not found
// - Logic Error: ex. css miss-placed, weird JS typing
//
// ![Debugging Strategies.png](attachment:dd80dcee-8bfe-4be5-9af5-ff674462e16c.png)
// ![Debugging Questions.PNG](attachment:c91b14e6-ab05-43f1-8cf9-7c45d2915af9.PNG)
